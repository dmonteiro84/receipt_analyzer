# %%
#!pip install pytesseract

import os
import glob
import pytesseract
from PIL import Image

# Specify the path to the Tesseract executable
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# Define the path to the 'data' subfolder
data_folder = 'data'

# Get a list of JPG files in the 'data' subfolder
jpg_files = glob.glob(os.path.join(data_folder, '*.jpg'))

# Loop through each JPG file and extract text
for jpg_file in jpg_files:
    # Open the image file
    image = Image.open(jpg_file)

    # Use pytesseract to extract text
    text = pytesseract.image_to_string(image)

    # Print the file name and extracted text
    print("File:", jpg_file)
    print("Text:", text)
    print("="*50)  # Separator for better readability
# Out:
# File: data\20240103_095408.jpg
# Text: Woolworths @
# The fresh ats
#
# 1442 Hascot PH: 02 8565 9333
# Cnr Chureh Ave and Kent Rd
# TAX INVOICE - ABN 88 000 014 675
#
# -
#
# ia
#
# :
#
# :
#
# ~ Banaha Cavendish
# 0.447 ka NET @ $4.50/ka
# Peach Yellow Flesh
# 0.242 kg NET @ $3.90/kg
# Carmans LC Granola Peanut Butter 425g
# #0B Finest Cracker Selection 160g
# Hacro Org Wholewheat Spirals 500g
# WS/Pots O/R Nut Mix 2006 eg
# 4$/Pots Cashew R&S 180g
# Jalna Greek Natural Yoghurt ikg
# Woolworths FreeRangeEggs 3509 6pk
# Thomas Dux Gruyere6mMatured 150g
# Old Telegraph Road Camembert 115g
# Thomas Dux Vintage Cheddar
# Dorsogna Natural Premium Ham 100g
#
# Woolworths Diamond Ciabatta Rolls 4pk 3.75
# WH Cheese Slices Swiss 200g 4.90
# Kiwi Fruit Green P/P 8pk Imported 9.90
# Berry Strawberry 250g P/P 1.70
# Mango Honey Gold 4.50
# Passionfruit Panama 2.00
#
# 19 SUBTOTAL
#
# ITAL
#
# | a
# tO
# or
# our
#
# —>
# =
# <1
# ——<— =
# Cie oe
#
# ...
# File: data\20240103_095432.jpg
# ...
